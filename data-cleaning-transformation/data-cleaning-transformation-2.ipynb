# %%
import pandas as pd

# %%
train = pd.read_csv("contents/test.csv")

# %%
train.describe(include="all")
# Out:
#                  Id            A     B            C            D     E     F  \
# count   1459.000000  1459.000000  1455  1232.000000  1459.000000  1459   107
# unique          NaN          NaN     5          NaN          NaN     2     2
# top             NaN          NaN    AO          NaN          NaN  Pave  Grvl
# freq            NaN          NaN  1114          NaN          NaN  1453    70
# mean     730.000000    57.378341   NaN    49.377435   688.540096   NaN   NaN
# std      421.321334    42.746880   NaN    30.346436   512.962555   NaN   NaN
# min        1.000000    20.000000   NaN    10.000000   240.000000   NaN   NaN
# 25%      365.500000    20.000000   NaN    30.000000   240.000000   NaN   NaN
# 50%      730.000000    50.000000   NaN    35.000000   600.000000   NaN   NaN
# 75%     1094.500000    70.000000   NaN    72.000000   840.000000   NaN   NaN
# max     1459.000000   190.000000   NaN   200.000000  2280.000000   NaN   NaN
#
# ...
